# %%
import requests

from bs4 import BeautifulSoup

# %%
url='https://www.mysmartprice.com/appliance/pricelist/godrej-microwave-oven-price-list-in-india.html'

# %%
response=requests.get(url)

response
# Out:
# <Response [200]>

# %%
mw=BeautifulSoup(response.text)

mw
# Out:
# <!DOCTYPE html>
# <html lang="en" xmlns="http://www.w3.org/1999/xhtml"><head><meta content="text/html; charset=utf-8" http-equiv="Content-Type"/><meta content="width=device-width, initial-scale=1.0, maximum-scale=1.0, user-scalable=0" name="viewport"/><meta content="en-uk, english" name="language"/><title>Godrej Microwave Ovens Price in India 2022 |  Godrej Microwave Ovens Price List </title><!--zz--> <title>  Price in India  2022-03-21</title><!--zz--> <link href="/osd.xml" rel="search" title="MySmartPrice" type="application/opensearchdescription+xml"/><style>/**
#  * Table of contents:
#  * msp_common_critical.css
#  * Generated: 2022-03-14 05:08:19
#  */
#
#
# /* Filename: msp_common_critical.css */
# ...

# %%
name=mw.select('.prdct-item__name')

name
# Out:
# [<a class="prdct-item__name" href="https://www.mysmartprice.com/appliance/godrej-gmx-519-cp1-19-l-convection-microwave-oven-msf564435" target="_blank">       Godrej GMX 519 CP1 19 L Convection Microwave Oven
#                      </a>,
#  <a class="prdct-item__name" href="https://www.mysmartprice.com/appliance/godrej-gmx-20ca5-mlz-20-l-convection-microwave-oven-msf564600" target="_blank">       Godrej GMX 20CA5-MLZ 20 L Convection Microwave Oven
#                      </a>,
#  <a class="prdct-item__name" href="https://www.mysmartprice.com/appliance/godrej-gmx-20ca6plz-20-l-convection-microwave-oven-msf564593" target="_blank">       Godrej GMX 20CA6PLZ 20 L Convection Microwave Oven
#                      </a>,
#  <a class="prdct-item__name" href="https://www.mysmartprice.com/appliance/godrej-gme-530-cr1-sz-30-l-convection-grill-microwave-oven-msf584817" target="_blank">       Godrej GME 530 CR1 SZ 30 L Convection &amp; Grill Microwave Oven
#                      </a>,
# ...

# %%
mw_name=[]

# %%
for item in name:
  mw_name.append(item.text)
  link="www.mysmartprice.com"+item["href"]


mw_name
# Out:
# ['       Godrej GMX 519 CP1 19 L Convection Microwave Oven\n                    ',
#  '       Godrej GMX 20CA5-MLZ 20 L Convection Microwave Oven\n                    ',
#  '       Godrej GMX 20CA6PLZ 20 L Convection Microwave Oven\n                    ',
#  '       Godrej GME 530 CR1 SZ 30 L Convection & Grill Microwave Oven\n                    ',
#  '       Godrej GMX 20SA2 BLM 20 L Solo Microwave Oven\n                    ',
#  '       Godrej GME 530 CF1 PM 30 L Convection Microwave Oven\n                    ',
#  '       Godrej GME 725 CF1 PZ 25 L Convection Microwave Oven\n                    ',
#  '       Godrej GME 528 CF1 PM 28 L Convection Microwave Oven\n                    ',
#  '       Godrej GME 730 CR1 PZ 30 L Convection Microwave Oven\n                    ',
#  '       Godrej GME 725 CF2 PZ 25 L Convection Microwave Oven\n                    ',
#  '       Godrej GME 720 CP2 QZ 20 L Convection Microwave Oven\n                    ',
# ...

# %%
price=mw.select(".prdct-item__prc-val")

price
# Out:
# [<span class="prdct-item__prc-val">8,440</span>,
#  <span class="prdct-item__prc-val">11,594</span>,
#  <span class="prdct-item__prc-val">6,231</span>,
#  <span class="prdct-item__prc-val">12,990</span>,
#  <span class="prdct-item__prc-val">4,990</span>,
#  <span class="prdct-item__prc-val">12,800</span>,
#  <span class="prdct-item__prc-val">13,439</span>,
#  <span class="prdct-item__prc-val">14,990</span>,
#  <span class="prdct-item__prc-val">13,699</span>,
#  <span class="prdct-item__prc-val">13,490</span>,
#  <span class="prdct-item__prc-val">10,599</span>,
#  <span class="prdct-item__prc-val">17,015</span>,
#  <span class="prdct-item__prc-val">16,290</span>,
#  <span class="prdct-item__prc-val">9,500</span>,
#  <span class="prdct-item__prc-val">15,955</span>,
#  <span class="prdct-item__prc-val">12,893</span>,
#  <span class="prdct-item__prc-val">9,240</span>,
#  <span class="prdct-item__prc-val">14,404</span>,
#  <span class="prdct-item__prc-val">14,299</span>,
# ...

# %%
mw_price=[]

# %%
for item in price:
  mw_price.append(item.text)

mw_price
# Out:
# ['8,440',
#  '11,594',
#  '6,231',
#  '12,990',
#  '4,990',
#  '12,800',
#  '13,439',
#  '14,990',
#  '13,699',
#  '13,490',
#  '10,599',
#  '17,015',
#  '16,290',
#  '9,500',
#  '15,955',
#  '12,893',
#  '9,240',
#  '14,404',
#  '14,299',
#  '23,090',
#  '15,990',
#  '12,900',
#  '11,490',
#  '13,897',
#  '8,999']

# %%
ratings=mw.select(".rtng-star__inr")

ratings
# Out:
# [<div class="rtng-star__inr" style="width: 86%;">
#  </div>, <div class="rtng-star__inr" style="width: 84%;">
#  </div>, <div class="rtng-star__inr" style="width: 86%;">
#  </div>, <div class="rtng-star__inr" style="width: 86%;">
#  </div>, <div class="rtng-star__inr" style="width: 86%;">
#  </div>, <div class="rtng-star__inr" style="width: 86%;">
#  </div>, <div class="rtng-star__inr" style="width: 88%;">
#  </div>, <div class="rtng-star__inr" style="width: 84%;">
#  </div>, <div class="rtng-star__inr" style="width: 82%;">
#  </div>, <div class="rtng-star__inr" style="width: 84%;">
#  </div>, <div class="rtng-star__inr" style="width: 0%;">
#  </div>, <div class="rtng-star__inr" style="width: 84%;">
#  </div>, <div class="rtng-star__inr" style="width: 76%;">
#  </div>, <div class="rtng-star__inr" style="width: 84%;">
#  </div>, <div class="rtng-star__inr" style="width: 84%;">
#  </div>, <div class="rtng-star__inr" style="width: 80%;">
# ...

# %%
import pandas as pd

# %%
microwave=pd.DataFrame(name,columns=['microwave Name'])
microwave
# Out:
#                                        microwave Name
# 0          Godrej GMX 519 CP1 19 L Convection Micr...
# 1          Godrej GMX 20CA5-MLZ 20 L Convection Mi...
# 2          Godrej GMX 20CA6PLZ 20 L Convection Mic...
# 3          Godrej GME 530 CR1 SZ 30 L Convection &...
# 4          Godrej GMX 20SA2 BLM 20 L Solo Microwav...
# 5          Godrej GME 530 CF1 PM 30 L Convection M...
# 6          Godrej GME 725 CF1 PZ 25 L Convection M...
# 7          Godrej GME 528 CF1 PM 28 L Convection M...
# 8          Godrej GME 730 CR1 PZ 30 L Convection M...
# 9          Godrej GME 725 CF2 PZ 25 L Convection M...
# 10         Godrej GME 720 CP2 QZ 20 L Convection M...
# 11         Godrej GME 733 CM1 SM 33 L Convection &...
# 12         Godrej GME 728 CIP3 RM 28 L Convection ...
# 13         Godrej GME 720 CF2 QZ 20 L Convection M...
# 14         Godrej GMX 30 CA1 SIM 30 L Convection M...
# 15         Godrej GMX 25CA1 MIZ 25 L Convection Mi...
# ...

# %%
microwave['microwave Rate']=mw_price

microwave
# Out:
#                                        microwave Name microwave Rate
# 0          Godrej GMX 519 CP1 19 L Convection Micr...          8,440
# 1          Godrej GMX 20CA5-MLZ 20 L Convection Mi...         11,594
# 2          Godrej GMX 20CA6PLZ 20 L Convection Mic...          6,231
# 3          Godrej GME 530 CR1 SZ 30 L Convection &...         12,990
# 4          Godrej GMX 20SA2 BLM 20 L Solo Microwav...          4,990
# 5          Godrej GME 530 CF1 PM 30 L Convection M...         12,800
# 6          Godrej GME 725 CF1 PZ 25 L Convection M...         13,439
# 7          Godrej GME 528 CF1 PM 28 L Convection M...         14,990
# 8          Godrej GME 730 CR1 PZ 30 L Convection M...         13,699
# 9          Godrej GME 725 CF2 PZ 25 L Convection M...         13,490
# 10         Godrej GME 720 CP2 QZ 20 L Convection M...         10,599
# 11         Godrej GME 733 CM1 SM 33 L Convection &...         17,015
# 12         Godrej GME 728 CIP3 RM 28 L Convection ...         16,290
# ...
